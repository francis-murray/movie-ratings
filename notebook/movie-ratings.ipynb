# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib as plt
# %matplotlib inline
import pandas as pd
import sys
sys.path.append("../")
import os
os.chdir('../')
import src.processing.process_keywords as pk

# %% [markdown]
# # Ratings des films

# %%
df = pk.raw()
kw = pk.get_keywords_of_film(df,111109)
print(kw)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e5de6b687020> in <module>
# ----> 1 df = pk.raw()
#       2 kw = pk.get_keywords_of_film(df,111109)
#       3 print(kw)
#
# ~/Documents/dev/movie-ratings/src/processing/process_keywords.py in raw()
#       8
#       9 def raw() :
# ---> 10     df = up.raw(filename)
#      11     return clean(df)
#      12
#
# ~/Documents/dev/movie-ratings/src/processing/util_processing.py in raw(filename, limit, all, dtype)
#       8 def raw(filename="",limit=1,all=True,dtype=None):
#       9     if all:
# ---> 10         return pd.read_csv(data_raw_dir+filename,dtype=dtype)
#      11     else:
#      12         return pd.read_csv(data_raw_dir+filename,dtype=dtype)[:limit]
#
# ...

# %%
plt.pyplot.scatter(df_ratings_small["timestamp"],df_ratings_small["rating"])
plt.pyplot.show()
